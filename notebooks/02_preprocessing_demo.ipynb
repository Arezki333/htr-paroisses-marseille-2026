# %% [markdown]
# # 02 — Démo du pipeline de prétraitement
#
# Ce notebook illustre et valide les étapes de prétraitement :
# 1. Chargement d'une image brute
# 2. Deskew (correction de l'inclinaison)
# 3. Amélioration du contraste (CLAHE)
# 4. Binarisation (Otsu / Sauvola)
# 5. Comparaison visuelle avant / après

# %%
from pathlib import Path
import matplotlib.pyplot as plt

from src.preprocessing.deskew import deskew
from src.preprocessing.enhance import binarize, enhance_contrast
from src.preprocessing.pipeline import run_pipeline

# Charger une image exemple
sample_image = None  # TODO: remplacer par un chemin réel
print('Pipeline prêt à être testé.')
