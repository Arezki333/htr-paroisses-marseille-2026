# %% [markdown]
# # 01 — Exploration du corpus
#
# Ce notebook explore les images téléchargées depuis les Archives Municipales de Marseille :
# - Distribution des sources (paroissiaux vs recensements)
# - Statistiques sur la résolution, le format et la taille des images
# - Visualisation d'échantillons représentatifs
# - Analyse de la diversité linguistique et des mains de scribes

# %%
from pathlib import Path
import json

RAW_PAROISSIAUX = Path('../data/raw/paroissiaux')
RAW_RECENSEMENTS = Path('../data/raw/recensements')

print('Paroissiaux :', len(list(RAW_PAROISSIAUX.glob('*'))))
print('Recensements :', len(list(RAW_RECENSEMENTS.glob('*'))))
